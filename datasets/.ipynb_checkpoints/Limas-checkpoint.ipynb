# %%
import numpy as np
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
plt.style.use('fivethirtyeight')
color_pal = sns.color_palette()

# %%
df = pd.read_excel('limas.xlsx')
df = df.set_index("Datetime")
pd.to_datetime(df.index)
# Out:
# DatetimeIndex(['2015-01-01', '2015-02-01', '2015-03-01', '2015-04-01',
#                '2015-05-01', '2015-06-01', '2015-07-01', '2015-08-01',
#                '2015-09-01', '2015-10-01', '2015-11-01', '2015-12-01',
#                '2016-01-01', '2016-02-01', '2016-03-01', '2016-04-01',
#                '2016-05-01', '2016-06-01', '2016-07-01', '2016-08-01',
#                '2016-10-01', '2016-11-01', '2016-12-01', '2017-01-01',
#                '2017-02-01', '2017-03-01', '2017-04-01', '2017-05-01',
#                '2017-06-01', '2017-07-01', '2017-08-01', '2017-09-01',
#                '2017-10-01', '2017-11-01', '2017-12-01', '2018-01-01',
#                '2018-02-01', '2018-03-01', '2018-04-01', '2018-05-01',
#                '2018-06-01', '2018-07-01', '2018-08-01', '2018-09-01',
#                '2018-10-01', '2018-11-01', '2018-12-01', '2019-01-01',
#                '2019-02-01', '2019-03-01', '2019-04-01', '2019-05-01',
#                '2019-06-01', '2019-07-01', '2019-08-01', '2019-09-01',
#                '2019-10-01', '2019-11-01', '2019-12-01', '2020-01-01',
#                '2020-02-01', '2020-03-01', '2020-04-01', '2020-05-01',
#                '2020-06-01', '2020-07-01', '2020-08-01', '2020-09-01',
#                '2020-10-01', '2020-11-01', '2020-12-01', '2021-01-01',
#                '2021-02-01', '2021-03-01', '2021-04-01', '2021-06-01',
#                '2021-07-01', '2021-08-01', '2021-09-01', '2021-10-01',
#                '2021-11-01', '2021-12-01', '2022-01-01', '2022-02-01',
#                '2022-03-01', '2022-04-01', '2022-05-01', '2022-06-01',
#                '2022-07-01', '2022-08-01', '2022-09-01'],
#               dtype='datetime64[ns]', name='Datetime', freq=None)

# %%
df.plot(style=".", figsize=(15,5), color=color_pal[0], title="LIMAS")
plt.show()

# %% [markdown]
# #### Test / Train Split

# %%
train = df.loc[df.index < "01-01-2020"]
test = df.loc[df.index >= "01-01-2020"]

fig, ax = plt.subplots(figsize=(15,5))
train.plot(ax=ax, label="Train Set", title="Data Train/Test Split")
test.plot(ax=ax, label="Test Set")
ax.axvline("01-01-2020", color="black", ls="--")
plt.show()

# %%
df.loc[(df.index > "01-01-2015") & (df.index < "01-01-2022")].plot()
# Out:
# <AxesSubplot:xlabel='Datetime'>

# %% [markdown]
# #### Feature Creation

# %%
def create_features(df):
    #create time series fatures based on time series index
    df= df.copy()
    df["month"] = df.index.month
    df["year"] = df.index.year
    df["quarter"] = df.index.quarter
    return df

df = create_features(df)

# %% [markdown]
# Visualización de las Features

# %%
fig, ax = plt.subplots()
sns.boxplot(data=df, x="year", y="Sales")
ax.set_title("Ventas de limas por año")
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(data=df, x="quarter", y="Sales")
ax.set_title("Ventas de limas por Trimestre")
plt.show()

# %%
fig, ax = plt.subplots()
sns.boxplot(data=df, x="month", y="Sales")
ax.set_title("Ventas de limas por mes")
plt.show()

# %% [markdown]
# #### Crear el modelo

# %%
train = create_features(train)
test = create_features(test)

# %%
df.columns
# Out:
# Index(['Sales', 'month', 'year', 'quarter'], dtype='object')

# %%
FEATURES = ["month", "year", "quarter"]
TARGET = "Sales"

# %%
X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(n_estimators=1000, early_stopping_rounds=50,
                      learning_rate=0.01)
reg.fit(X_train, y_train,
       eval_set=[(X_train, y_train), (X_test, y_test)],
       verbose=100)
# Out:
# [0]	validation_0-rmse:48193.21358	validation_1-rmse:61446.02749
# [100]	validation_0-rmse:25668.00244	validation_1-rmse:47748.47808
# [200]	validation_0-rmse:15611.21861	validation_1-rmse:45528.57455
# [270]	validation_0-rmse:11222.47609	validation_1-rmse:45635.68222
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
            index=reg.feature_names_in_,
            columns=["importance"])

# %%
fi.sort_values("importance").plot(kind="barh", title="Feature Importance")
plt.show()

# %% [markdown]
# #### Forecast en Test

# %%
test["prediction"] = reg.predict(X_test)

# %%
df = df.merge(test[["prediction"]], how="left", left_index=True, right_index=True)

# %%
df
# Out:
#             Sales  month  year  quarter   prediction
# Datetime
# 2015-01-01   4173      1  2015        1          NaN
# 2015-02-01  10667      2  2015        1          NaN
# 2015-03-01    797      3  2015        1          NaN
# 2015-04-01   2808      4  2015        2          NaN
# 2015-05-01   5886      5  2015        2          NaN
# ...           ...    ...   ...      ...          ...
# 2022-05-01  24153      5  2022        2  3383.229736
# 2022-06-01  13789      6  2022        2  1108.771484
# 2022-07-01  22490      7  2022        3  4460.768555
# 2022-08-01  21581      8  2022        3  3935.444580
# 2022-09-01  19140      9  2022        3  5731.519531
#
# [91 rows x 5 columns]

# %%
ax = df[["Sales"]].plot(figsize=(15, 5))
df["prediction"].plot(ax=ax, style=".")
ax.set_title("Raw Dat and Prediction")
plt.show()

# %%
ax = df.loc[(df.index > "01-01-2020") & (df.index < "01-01-2022")]["Sales"] \
    .plot(figsize=(15, 5), title="Limas Triangulares")
df.loc[(df.index > "01-01-2020") & (df.index < "01-01-2022")]["prediction"] \
    .plot(style=".")
plt.legend(["Truth data", "Prediction"])
plt.show()

# %% [markdown]
# #### Calcular error

# %%
score = np.sqrt(mean_squared_error(test["Sales"], test["prediction"]))
print(f"RMSE Score on Test set: {score:0.2f}")
# Out:
# RMSE Score on Test set: 45496.18

# %%
test["error"] = np.abs(test[TARGET] - test["prediction"])

# %%
test["date"] = test.index.date

# %%
test.groupby(["date"])["error"].mean().sort_values(ascending=False).head(5)
# Out:
# date
# 2022-02-01    99909.338135
# 2021-11-01    93414.244141
# 2020-12-01    80662.657227
# 2021-02-01    80065.338135
# 2021-06-01    74759.228516
# Name: error, dtype: float64

# %%
test.groupby(["date"])["error"].mean().sort_values(ascending=True).head(5)
# Out:
# date
# 2020-05-01     367.229736
# 2020-04-01    1339.770264
# 2020-08-01    2610.555420
# 2020-09-01    6008.480469
# 2022-01-01    7742.617188
# Name: error, dtype: float64
